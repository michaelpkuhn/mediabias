# %%
# %matplotlib inline
import os
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func
from sqlalchemy import create_engine, inspect
import requests
from flask import Flask, jsonify, render_template, redirect, make_response, json
import sys
import sqlalchemy.dialects.postgresql
from flask_sqlalchemy import SQLAlchemy
import base64
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#pw = base64.b64decode(b'a2VubndvcnQ=').decode("utf-8")
#db_url = F"postgres://postgres:{pw}@localhost/mediabias"
#db_url ='postgres://vigleotgdkofne:42870962558c95a8818d4a758b4e989db94e92654344ab44d26537f528a8bc81@ec2-34-195-169-25.compute-1.amazonaws.com:5432/d3cp995qbfoemo'
#engine = create_engine(db_url)

#DATABASE SET UP
uri = 'postgres://vigleotgdkofne:42870962558c95a8818d4a758b4e989db94e92654344ab44d26537f528a8bc81@ec2-34-195-169-25.compute-1.amazonaws.com:5432/d3cp995qbfoemo'
engine = create_engine(uri)
session = Session(engine)

# %%
engine
# Out:
# Engine(postgres://vigleotgdkofne:***@ec2-34-195-169-25.compute-1.amazonaws.com:5432/d3cp995qbfoemo)

# %%
#control for independent variable, cofounding factor: number of tweets
import matplotlib
matplotlib.pyplot.close("all")

# %%
query = "select * from final_db"

results = engine.execute(query).fetchall()
results[:2]
# Out:
# [('www.washingtonpost.com', 11607, Decimal('-0.300'), Decimal('-0.145'), Decimal('0.331'), Decimal('0.224'), Decimal('0.003'), Decimal('0.002')),
#  ('www.nytimes.com', 11140, Decimal('-0.325'), Decimal('-0.163'), Decimal('0.321'), Decimal('0.219'), Decimal('0.003'), Decimal('0.002'))]

# %% [markdown]
# y = x + z
# where
# y = estimated nominate_dim1
# x = avg(nominate_dim1 of politicians)
# z = avg(number of tweets from politicians)

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame(results,columns=["Site","count","nominate_dim1","nominate_dim2", 'dim1_stddev', 'dim2_stddev', 'dim1_stderr', 'dim2_stderr'])
df = df.astype({'nominate_dim1':'float32','nominate_dim2':'float32', 'dim1_stddev':'float32', 'dim2_stddev':'float32', 'dim1_stderr':'float32', 'dim2_stderr':'float32'})

dim1_ls = np.array(df['nominate_dim1']).reshape(-1, 1)
#total_ls = list(df['total'])

# %%
df
# Out:
#                         Site  count  nominate_dim1  nominate_dim2  \
# 0     www.washingtonpost.com  11607         -0.300         -0.145
# 1            www.nytimes.com  11140         -0.325         -0.163
# 2            www.youtube.com   6648          0.080         -0.056
# 3           www.facebook.com   5558         -0.124         -0.102
# 4                thehill.com   4295         -0.098         -0.090
# ...                      ...    ...            ...            ...
# 6206            wyo4news.com      2          0.539          0.237
# 6207  wyomingpublicmedia.org      2          0.048         -0.250
# 6208           yeson1631.org      2         -0.696         -0.234
# 6209          ymca-snoco.org      2         -0.365          0.189
# 6210                 zoa.org      2          0.624         -0.333
#
#       dim1_stddev  dim2_stddev  dim1_stderr  dim2_stderr
# 0           0.331        0.224        0.003        0.002
# 1           0.321        0.219        0.003        0.002
# ...

# %%
plt.close('all')

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from sklearn import neighbors, datasets

n_neighbors=len(df)//3 #6211
print(n_neighbors)

target = [0]*n_neighbors + [1] *(n_neighbors+1) + [2] * n_neighbors
dim1 = list(df['nominate_dim1'])
dim2 = list(df['nominate_dim2'])

X = np.array([[x, dim2[i]] for i, x in enumerate(dim1)])
y=target

h= .02


cmap_light = ListedColormap(['orange', 'cyan', 'cornflowerblue'])
cmap_bold = ListedColormap(['darkorange', 'c', 'darkblue'])

for weights in ['uniform', 'distance']:
    # we create an instance of Neighbours Classifier and fit the data.
    clf = neighbors.KNeighborsClassifier(n_neighbors, weights=weights)
    clf.fit(X, y)

    # Plot the decision boundary. For that, we will assign a color to each
    # point in the mesh [x_min, x_max]x[y_min, y_max].
    x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
    y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                         np.arange(y_min, y_max, h))
    Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])

    # Put the result into a color plot
    Z = Z.reshape(xx.shape)
    plt.figure()
    plt.pcolormesh(xx, yy, Z, cmap=cmap_light)

    # Plot also the training points
    plt.scatter(X[:, 0], X[:, 1], c=y, cmap=cmap_bold,
                edgecolor='k', s=20)
    plt.xlim(xx.min(), xx.max())
    plt.ylim(yy.min(), yy.max())
    plt.title("3-Class classification (k = %i, weights = '%s')"
              % (n_neighbors, weights))

plt.show()
# Out:
# 2070

# %%
point = np.array([-0.465, -0.195]).reshape(1,-1)

clf.predict(point)

predictions = []
for pt in X:
    pt = pt.reshape(1,-1)
    p = clf.predict(pt)
    if p[0] == 0:
        p_label = 'Liberal'
    elif p[0] == 1:
        p_label = 'Moderate'
    else:
        p_label = 'Conservative'
    predictions.append(p_label)

# %%
df['Group'] = predictions
df.sort_values('nominate_dim1')
# Out:
#                                    Site  count  nominate_dim1  nominate_dim2  \
# 5548            www.elizabethwarren.com      2         -0.767         -0.268
# 3057                           ewar.ren      4         -0.767         -0.268
# 995                 elizabethwarren.com     18         -0.738         -0.246
# 4777                      hbswk.hbs.edu      2         -0.732         -0.251
# 633              my.elizabethwarren.com     30         -0.728         -0.246
# ...                                 ...    ...            ...            ...
# 4816               houselive.gov. #AZ05      2          0.882         -0.471
# 4504                            aul.org      2          0.882         -0.471
# 4897  lightningstream.surfernetwork.com      2          0.882         -0.471
# 2873               www.leeforsenate.com      5          0.913         -0.408
# 6159                        www.wgu.edu      2          0.913         -0.408
#
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from sklearn import neighbors, datasets

n_neighbors= len(df)//5

target2 = [0]*n_neighbors + [1] * n_neighbors + [2] * (n_neighbors+1) + [3]*n_neighbors + [4] *n_neighbors
dim1 = list(df['nominate_dim1'])
dim2 = list(df['nominate_dim2'])

X = np.array([[x, dim2[i]] for i, x in enumerate(dim1)])
y=target2

h= .1


cmap_light = ListedColormap(['cornflowerblue','cyan','grey', 'orange', 'red'])
cmap_bold = ListedColormap(['darkblue', 'c', 'slategray', 'darkorange', 'firebrick'])

for weights in ['uniform', 'distance']:
    # we create an instance of Neighbours Classifier and fit the data.
    clf = neighbors.KNeighborsClassifier(n_neighbors, weights=weights)
    clf.fit(X, y)

    # Plot the decision boundary. For that, we will assign a color to each
    # point in the mesh [x_min, x_max]x[y_min, y_max].
    x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
    y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                         np.arange(y_min, y_max, h))
    Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])

    # Put the result into a color plot
    Z = Z.reshape(xx.shape)
    plt.figure()
    plt.pcolormesh(xx, yy, Z, cmap=cmap_light)

    # Plot also the training points
    plt.scatter(X[:, 0], X[:, 1], c=y, cmap=cmap_bold,
                edgecolor='k', s=20)
    plt.xlim(xx.min(), xx.max())
    plt.ylim(yy.min(), yy.max())
    plt.title("5-Class classification (k = %i, weights = '%s')"
              % (n_neighbors, weights))

#plt.savefig('static/images/5class.png')

# %%
predictions = []
for pt in X:
    pt = pt.reshape(1,-1)
    p = clf.predict(pt)
    if p[0] == 0:
        p_label = 'Left'
    elif p[0] == 1:
        p_label = 'Left-Leaning'
    elif p[0] == 2:
        p_label = 'Moderate'
    elif p[0] == 3:
        p_label = 'Right-Leaning'
    else:
        p_label = 'Right'
    predictions.append(p_label)
df4['Group'] = predictions
df4
# Out:
#                           Site  nominate_dim1  nominate_dim2          Group
# 0          www.motherjones.com         -0.465         -0.195           Left
# 1             theintercept.com         -0.454         -0.284           Left
# 2                  www.vox.com         -0.434         -0.176           Left
# 3       www.huffingtonpost.com         -0.426         -0.181           Left
# 4            thinkprogress.org         -0.422         -0.201           Left
# 5                    slate.com         -0.421         -0.242           Left
# 6          www.nydailynews.com         -0.404         -0.212           Left
# 7                www.msnbc.com         -0.387         -0.140   Left-Leaning
# 8            www.newyorker.com         -0.360         -0.179   Left-Leaning
# 9                  www.npr.org         -0.347         -0.129   Left-Leaning
# 10            www.buzzfeed.com         -0.336         -0.158   Left-Leaning
# ...

# %%
df_1000 = df[:1000]

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from sklearn import neighbors, datasets
from sklearn.model_selection import train_test_split
from sklearn.neighbors import (NeighborhoodComponentsAnalysis, KNeighborsClassifier)
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler


n_neighbors= len(df_1000)//5

print(n_neighbors)

target2 = [0]*n_neighbors + [1] * n_neighbors + [2] * n_neighbors + [3]*n_neighbors + [4] *n_neighbors
dim1 = list(df_1000['nominate_dim1'])
dim2 = list(df_1000['nominate_dim2'])

X = np.array([[x, dim2[i]] for i, x in enumerate(dim1)])
y=target2

X_train, X_test, y_train, y_test = train_test_split(X,y, stratify=y, test_size=0.7,
                                                   random_state=42)
h= .02


cmap_light = ListedColormap(['cornflowerblue','cyan','grey', 'orange', 'red'])
cmap_bold = ListedColormap(['darkblue', 'c', 'slategray', 'darkorange', 'firebrick'])

names = ['KNN', 'NCA, KNN']

classifiers = [Pipeline([('scalar', StandardScaler()),
                       ('knn', KNeighborsClassifier(n_neighbors=n_neighbors))]),
              Pipeline([('scalar', StandardScaler()),
                       ('nca', NeighborhoodComponentsAnalysis()),
                       ('knn', KNeighborsClassifier(n_neighbors=n_neighbors))])
              ]

x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                     np.arange(y_min, y_max, h))

for name, clf in zip(names, classifiers):
    # we create an instance of Neighbours Classifier and fit the data.
    clf.fit(X_train, y_train)
    score =clf.score(X_test, y_test)

    # Plot the decision boundary. For that, we will assign a color to each

    Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])

    # Put the result into a color plot
    Z = Z.reshape(xx.shape)
    plt.figure()
    plt.pcolormesh(xx, yy, Z, cmap=cmap_light)

    # Plot also the training points
    plt.scatter(X[:, 0], X[:, 1], c=y, cmap=cmap_bold,
                edgecolor='k', s=20)
    plt.xlim(xx.min(), xx.max())
    plt.ylim(yy.min(), yy.max())
    plt.title("{} (k = {})".format(name, n_neighbors))
    plt.text(0.9, 0.1, '{:.2f}'.format(score), size=15,
             ha='center', va='center', transform=plt.gca().transAxes)


plt.savefig('static/images/knn_overload.png')

plt.show()
# Out:
# 200

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from sklearn import neighbors, datasets
from sklearn.model_selection import train_test_split
from sklearn.neighbors import (NeighborhoodComponentsAnalysis, KNeighborsClassifier)
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans


n_clusters = 5

target2 = [0]*n_neighbors + [1] * n_neighbors + [2] * n_neighbors + [3]*n_neighbors + [4] *n_neighbors

dim1 = list(df_1000['nominate_dim1'])
dim2 = list(df_1000['nominate_dim2'])

X = np.array([[x, dim2[i]] for i, x in enumerate(dim1)])
y=target2


km = KMeans(
    n_clusters=5, init='random',
    n_init=10, max_iter=300, 
    tol=1e-04, random_state=0
)

y_km = km.fit_predict(X)

# plot the 3 clusters
plt.scatter(
    X[y_km == 0, 0], X[y_km == 0, 1],
    s=50, c='grey',
    marker='s', edgecolor='black',
    label='cluster 1'
)

plt.scatter(
    X[y_km == 1, 0], X[y_km == 1, 1],
    s=50, c='pink',
    marker='o', edgecolor='black',
    label='cluster 2'
)

plt.scatter(
    X[y_km == 2, 0], X[y_km == 2, 1],
    s=50, c='firebrick',
    marker='v', edgecolor='black',
    label='cluster 3'
)

plt.scatter(
    X[y_km == 3, 0], X[y_km == 3, 1],
    s=50, c='lightblue',
    marker='o', edgecolor='black',
    label='cluster 4'
)

plt.scatter(
    X[y_km == 4, 0], X[y_km == 4, 1],
    s=50, c='blue',
    marker='v', edgecolor='black',
    label='cluster 5'
)

# plot the centroids
plt.scatter(
    km.cluster_centers_[:, 0], km.cluster_centers_[:, 1],
    s=250, marker='*',
    c='yellow', edgecolor='black',
    label='centroids'
)


plt.legend(scatterpoints=1)
plt.grid()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from sklearn import neighbors, datasets
from sklearn.model_selection import train_test_split
from sklearn.neighbors import (NeighborhoodComponentsAnalysis, KNeighborsClassifier)
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans


n_clusters = 5

target2 = [0]*n_neighbors + [1] * n_neighbors + [2] * n_neighbors + [3]*n_neighbors + [4] *n_neighbors

dim1 = list(df['nominate_dim1'])
dim2 = list(df['nominate_dim2'])

X = np.array([[x, dim2[i]] for i, x in enumerate(dim1)])
y=target2


km = KMeans(
    n_clusters=5,
    n_init=10, max_iter=300, 
    tol=1e-04, random_state=0
)

y_km = km.fit_predict(X)

# plot the 3 clusters
plt.scatter(
    X[y_km == 0, 0], X[y_km == 0, 1],
    s=50, c='lightblue',
    marker='s', edgecolor='black',
    label='Left-Leaning'
)

plt.scatter(
    X[y_km == 1, 0], X[y_km == 1, 1],
    s=50, c='pink',
    marker='o', edgecolor='black',
    label='Right-Leaning'
)

plt.scatter(
    X[y_km == 2, 0], X[y_km == 2, 1],
    s=50, c='firebrick',
    marker='v', edgecolor='black',
    label='Right'
)

plt.scatter(
    X[y_km == 3, 0], X[y_km == 3, 1],
    s=50, c='blue',
    marker='o', edgecolor='black',
    label='Left'
)

plt.scatter(
    X[y_km == 4, 0], X[y_km == 4, 1],
    s=50, c='grey',
    marker='v', edgecolor='black',
    label='Moderate'
)

# plot the centroids
plt.scatter(
    km.cluster_centers_[:, 0], km.cluster_centers_[:, 1],
    s=250, marker='*',
    c='yellow', edgecolor='black',
    label='centroids'
)


#plt.legend(scatterpoints=1)
plt.legend(bbox_to_anchor=(-.5,1), loc='upper left', ncol=1)
plt.grid()

plt.savefig('static/images/kmeans.png')

plt.show()

# %%
predictions = []
for pt in X:
    pt = pt.reshape(1,-1)
    p = km.predict(pt)
    if p[0] == 0:
        p_label = 'Left-Leaning'
    elif p[0] == 1:
        p_label = 'Right-Leaning'
    elif p[0] == 2:
        p_label = 'Right'
    elif p[0] == 3:
        p_label = 'Left'
    else:
        p_label = 'Moderate'
    predictions.append(p_label)
df['Group'] = predictions

# %%
df.sort_values('nominate_dim1')
# Out:
#                                    Site  count  nominate_dim1  nominate_dim2  \
# 5548            www.elizabethwarren.com      2         -0.767         -0.268
# 3057                           ewar.ren      4         -0.767         -0.268
# 995                 elizabethwarren.com     18         -0.738         -0.246
# 4777                      hbswk.hbs.edu      2         -0.732         -0.251
# 633              my.elizabethwarren.com     30         -0.728         -0.246
# ...                                 ...    ...            ...            ...
# 4816               houselive.gov. #AZ05      2          0.882         -0.471
# 4504                            aul.org      2          0.882         -0.471
# 4897  lightningstream.surfernetwork.com      2          0.882         -0.471
# 2873               www.leeforsenate.com      5          0.913         -0.408
# 6159                        www.wgu.edu      2          0.913         -0.408
#
# ...

# %%
news_ls = ['www.washingtonpost.com', 'www.nytimes.com', 'thehill.com', 'www.politico.com', 'www.cnn.com',
'www.wsj.com', 'www.foxnews.com', 'www.vox.com', 'www.usatoday.com', 'www.nbcnews.com', 'www.washingtonexaminer.com',
'www.npr.org', 'www.apnews.com', 'www.bloomberg.com', 'www.huffingtonpost.com', 'www.axios.com', 'www.breitbart.com',
'www.chicagotribune.com', 'www.nationalreview.com', 'freebeacon.com', 'www.msnbc.com','apple.news','www.newsweek.com'
'www.forbes.com', 'www.buzzfeed.com', 'www.foxbusiness.com', 'www.nydailynews.com', 'thinkprogress.org', 'www.motherjones.com',
'nypost.com', 'www.newyorker.com', 'www.pbs.org', 'thefederalist.com', 'reason.com', 'theintercept.com', 'slate.com',
'www.dailywire.com', 'www.conservativereview.com', 'www.reuters.com']
df.loc[df['Site'].isin(news_ls)].sort_values('nominate_dim1')
# Out:
#                            Site  count  nominate_dim1  nominate_dim2  \
# 69          www.motherjones.com    300         -0.465         -0.195
# 101            theintercept.com    216         -0.454         -0.284
# 12                  www.vox.com   2030         -0.434         -0.176
# 18       www.huffingtonpost.com   1485         -0.424         -0.189
# 63            thinkprogress.org    320         -0.422         -0.201
# 115                   slate.com    181         -0.421         -0.242
# 61          www.nydailynews.com    329         -0.404         -0.212
# 48                www.msnbc.com    421         -0.387         -0.140
# 79            www.newyorker.com    270         -0.360         -0.179
# 30             www.buzzfeed.com    645         -0.359         -0.167
# 13                  www.npr.org   1890         -0.345         -0.128
# 1               www.nytimes.com  11140         -0.325         -0.163
# 10              www.nbcnews.com   2300         -0.317         -0.123
# ...

# %%
# calculate distortion for a range of number of cluster
distortions = []
for i in range(1, 11):
    km = KMeans(
        n_clusters=i, init='random',
        n_init=10, max_iter=300,
        tol=1e-04, random_state=0
    )
    km.fit(X)
    distortions.append(km.inertia_)

# plot
plt.plot(range(1, 11), distortions, marker='o')
plt.xlabel('Number of clusters')
plt.ylabel('Distortion')
plt.show()

# %%
df.describe()
# Out:
#               count  nominate_dim1  nominate_dim2  dim1_stddev  dim2_stddev  \
# count   6211.000000    6211.000000    6211.000000  6211.000000  6211.000000
# mean      28.779907       0.016373      -0.046713     0.183274     0.142413
# std      270.284197       0.403610       0.210894     0.198102     0.126042
# min        2.000000      -0.767000      -0.961000     0.000000     0.000000
# 25%        2.000000      -0.362000      -0.176000     0.004000     0.004500
# 50%        4.000000      -0.048000      -0.051000     0.104000     0.136000
# 75%       11.000000       0.416000       0.084000     0.338000     0.228000
# max    11607.000000       0.913000       0.699000     1.113000     0.965000
#
#        dim1_stderr  dim2_stderr
# count  6211.000000  6211.000000
# mean      0.093546     0.074088
# std       0.142983     0.095570
# min       0.000000     0.000000
# 25%       0.002000     0.002000
# 50%       0.041000     0.044000
# 75%       0.115000     0.100000
# ...

# %%
#df['nominate_dim1'].plot.hist()
dim1.plot.kde(xlim=[-1,1])

# %%
from scipy.stats import gaussian_kde

kernel = gaussian_kde(dim1)

x = np.array([i for i in np.arange(-1,1,0.01)])
y = np.array([kernel(v)[0] for v in x])

plt.plot(x,y)
plt.scatter(real_roots[4:], kernel(real_roots[4:]),c="red")
plt.savefig('static/images/kde.png')
# Out:
# C:\Users\kuhnie\Anaconda3\lib\site-packages\scipy\stats\kde.py:261: ComplexWarning: Casting complex values to real discards the imaginary part
#   result[i] = sum(exp(-energy)*self.weights, axis=0)
# C:\Users\kuhnie\Anaconda3\lib\site-packages\numpy\core\_asarray.py:138: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order, subok=True)

# %%
from scipy.signal import argrelextrema
mi, ma = argrelextrema(y, np.less)[0], argrelextrema(y, np.greater)[0]
print("Minima:", y[mi])
print("Maxima:", y[ma])
# Out:
# Minima: [0.47199935]
# Maxima: [1.39593841 0.98720755]

# %%
y_dy = np.diff(y, axis=0)

plt.plot(x[:199],y_dy)

# %%
y_ddy = np.diff(y_dy,axis=0)

plt.plot(x[:198], y_ddy)

# %%
for degree in [2,4,5]:
    coefs, res, _, _, _ = np.polyfit(x[:198],y_ddy,degree, full = True)
    print(degree, res)
# Out:
# 2 [0.00175579]
# 4 [0.00174738]
# 5 [0.00171519]

# %%
import warnings

p = np.poly1d(y_ddy)

xp = np.linspace(-1,0.913)

with warnings.catch_warnings():
    warnings.simplefilter('ignore', np.RankWarning)
    p30 = np.poly1d(np.polyfit(x[:198], y_ddy, 30))

    
plt.plot(x[:198],y_ddy, '.', xp, p(xp), '-', xp, p30(xp), '--')

p30_roots = p30.r
real_roots = p30_roots[~np.iscomplex(p30_roots)]

plt.scatter(real_roots, p30(real_roots),c="red")
# Out:
# C:\Users\kuhnie\Anaconda3\lib\site-packages\numpy\core\_asarray.py:138: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order, subok=True)

# %%
class_ls = []
for row in df['nominate_dim1']:
    if row < -0.6:
        class_ls.append('Far Left')
    elif row < -0.4:
        class_ls.append('Left')
    elif row < -0.2:
        class_ls.append('Left-Leaning')
    elif row < 0.2:
        class_ls.append('Moderate')
    elif row < 0.4:
        class_ls.append('Right-Leaning')
    elif row < 0.6:
        class_ls.append('Right')
    else:
        class_ls.append('Far Right')

# %%
df['Group'] = class_ls
df.sort_values('nominate_dim1')
# Out:
#                                    Site  count  nominate_dim1  nominate_dim2  \
# 5548            www.elizabethwarren.com      2         -0.767         -0.268
# 3057                           ewar.ren      4         -0.767         -0.268
# 995                 elizabethwarren.com     18         -0.738         -0.246
# 4777                      hbswk.hbs.edu      2         -0.732         -0.251
# 633              my.elizabethwarren.com     30         -0.728         -0.246
# ...                                 ...    ...            ...            ...
# 4816               houselive.gov. #AZ05      2          0.882         -0.471
# 4504                            aul.org      2          0.882         -0.471
# 4897  lightningstream.surfernetwork.com      2          0.882         -0.471
# 2873               www.leeforsenate.com      5          0.913         -0.408
# 6159                        www.wgu.edu      2          0.913         -0.408
#
# ...

# %%
news_ls = ['www.washingtonpost.com', 'www.nytimes.com', 'thehill.com', 'www.politico.com', 'www.cnn.com',
'www.wsj.com', 'www.foxnews.com', 'www.vox.com', 'www.usatoday.com', 'www.nbcnews.com', 'www.washingtonexaminer.com',
'www.npr.org', 'www.apnews.com', 'www.bloomberg.com', 'www.huffingtonpost.com', 'www.axios.com', 'www.breitbart.com',
'www.chicagotribune.com', 'www.nationalreview.com', 'freebeacon.com', 'www.msnbc.com','apple.news','www.newsweek.com'
'www.forbes.com', 'www.buzzfeed.com', 'www.foxbusiness.com', 'www.nydailynews.com', 'thinkprogress.org', 'www.motherjones.com',
'nypost.com', 'www.newyorker.com', 'www.pbs.org', 'thefederalist.com', 'reason.com', 'theintercept.com', 'slate.com',
'www.dailywire.com', 'www.conservativereview.com', 'www.reuters.com']
df.loc[df['Site'].isin(news_ls)].sort_values('nominate_dim1').reset_index(drop=True)
# Out:
#                           Site  count  nominate_dim1  nominate_dim2  \
# 0          www.motherjones.com    300         -0.465         -0.195
# 1             theintercept.com    216         -0.454         -0.284
# 2                  www.vox.com   2030         -0.434         -0.176
# 3       www.huffingtonpost.com   1485         -0.424         -0.189
# 4            thinkprogress.org    320         -0.422         -0.201
# 5                    slate.com    181         -0.421         -0.242
# 6          www.nydailynews.com    329         -0.404         -0.212
# 7                www.msnbc.com    421         -0.387         -0.140
# 8            www.newyorker.com    270         -0.360         -0.179
# 9             www.buzzfeed.com    645         -0.359         -0.167
# 10                 www.npr.org   1890         -0.345         -0.128
# 11             www.nytimes.com  11140         -0.325         -0.163
# 12             www.nbcnews.com   2300         -0.317         -0.123
# ...

# %%
news_ls2 = ['www.washingtonpost.com', 'www.nytimes.com', 'thehill.com', 'www.politico.com', 'www.cnn.com',
'www.wsj.com', 'www.foxnews.com', 'www.vox.com', 'www.washingtonexaminer.com',
'www.npr.org', 'www.apnews.com', 'www.bloomberg.com', 'www.huffingtonpost.com', 'www.axios.com', 'www.breitbart.com',
'www.chicagotribune.com', 'www.nationalreview.com', 'freebeacon.com', 'www.msnbc.com','apple.news','www.newsweek.com'
'www.forbes.com', 'www.buzzfeed.com', 'www.foxbusiness.com', 'thinkprogress.org', 'www.motherjones.com',
'nypost.com', 'www.newyorker.com', 'www.pbs.org', 'thefederalist.com', 'reason.com', 'theintercept.com', 'slate.com',
'www.dailywire.com', 'www.conservativereview.com', 'www.reuters.com']
df.loc[df['Site'].isin(news_ls2)].sort_values('nominate_dim1').reset_index(drop=True)
# Out:
#                           Site  count  nominate_dim1  nominate_dim2  \
# 0          www.motherjones.com    300         -0.465         -0.195
# 1             theintercept.com    216         -0.454         -0.284
# 2                  www.vox.com   2030         -0.434         -0.176
# 3       www.huffingtonpost.com   1485         -0.424         -0.189
# 4            thinkprogress.org    320         -0.422         -0.201
# 5                    slate.com    181         -0.421         -0.242
# 6                www.msnbc.com    421         -0.387         -0.140
# 7            www.newyorker.com    270         -0.360         -0.179
# 8             www.buzzfeed.com    645         -0.359         -0.167
# 9                  www.npr.org   1890         -0.345         -0.128
# 10             www.nytimes.com  11140         -0.325         -0.163
# 11                 www.pbs.org    262         -0.312         -0.155
# 12      www.washingtonpost.com  11607         -0.300         -0.145
# ...

# %%
fig, ax = plt.subplots()

dim1 = df['nominate_dim1']
dim2 = df['nominate_dim2']

ax.axvspan(-1,-0.6, alpha=0.5, color='darkblue')
ax.axvspan(-0.6,-0.4, alpha=0.5, color='lightblue')
ax.axvspan(-0.4,-0.2, alpha=0.5, color='lightblue')
ax.axvspan(-0.2,0.2, alpha=0.5, color='grey')
ax.axvspan(0.2,0.4, alpha=0.5, color='pink')
ax.axvspan(0.4,0.6, alpha=0.5, color='red')
ax.axvspan(0.6,1, alpha=0.5, color='firebrick')


ax.scatter(dim1, dim2, c='black', alpha=0.75, zorder=2, edgecolors='white')

ax.set_ylim(-1,1)
ax.set_ylabel('NOMINATE Dimension 2')
ax.set_xlim(-1,1)
ax.set_xlabel('NOMINATE Dimension 1')

fig.set_figheight(10)
fig.set_figwidth(10)
fig.suptitle('DW-Equivalent Scores with Visual Bins', size='xx-large', y=0.93)

plt.savefig('static/images/fixed_bins.png')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-a52d19e66c6c> in <module>
# ----> 1 fig, ax = plt.subplots()
#       2
#       3 dim1 = df['nominate_dim1']
#       4 dim2 = df['nominate_dim2']
#       5
#
# NameError: name 'plt' is not defined
