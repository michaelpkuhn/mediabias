# %%
# %matplotlib inline
import os
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func
from sqlalchemy import create_engine, inspect
import requests
from flask import Flask, jsonify, render_template, redirect, make_response, json
import sys
import sqlalchemy.dialects.postgresql
from flask_sqlalchemy import SQLAlchemy
import base64
import pandas as pd
import numpy as np

# %%
#DATABASE SET UP
uri = 'postgres://vigleotgdkofne:42870962558c95a8818d4a758b4e989db94e92654344ab44d26537f528a8bc81@ec2-34-195-169-25.compute-1.amazonaws.com:5432/d3cp995qbfoemo'
#app.config['SQLALCHEMY_DATABASE_URI'] = uri
db = SQLAlchemy(uri)
engine = db.engine
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-957b98dd769a> in <module>
#       2 uri = 'postgres://vigleotgdkofne:42870962558c95a8818d4a758b4e989db94e92654344ab44d26537f528a8bc81@ec2-34-195-169-25.compute-1.amazonaws.com:5432/d3cp995qbfoemo'
#       3 #app.config['SQLALCHEMY_DATABASE_URI'] = uri
# ----> 4 db = SQLAlchemy(uri)
#       5 engine = db.engine
#
# ~\Anaconda3\lib\site-packages\flask_sqlalchemy\__init__.py in __init__(self, app, use_native_unicode, session_options, metadata, query_class, model_class, engine_options)
#     721
#     722         if app is not None:
# --> 723             self.init_app(app)
#     724
#     725     @property
#
# ~\Anaconda3\lib\site-packages\flask_sqlalchemy\__init__.py in init_app(self, app)
#     808         """
#     809         if (
# --> 810             'SQLALCHEMY_DATABASE_URI' not in app.config and
#     811             'SQLALCHEMY_BINDS' not in app.config
#     812         ):
#
# AttributeError: 'str' object has no attribute 'config'

# %%
session = Session(engine)

# %%
import pandas as pd
df = pd.DataFrame(results,columns=["Site","Count","nominate_dim1","nominate_dim2"])
df = df.astype({'nominate_dim1':'float32','nominate_dim2':'float32'})
df.dtypes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-a5414f4040ee> in <module>
#       1 import pandas as pd
# ----> 2 df = pd.DataFrame(results,columns=["Site","Count","nominate_dim1","nominate_dim2"])
#       3 df = df.astype({'nominate_dim1':'float32','nominate_dim2':'float32'})
#       4 df.dtypes
#
# NameError: name 'results' is not defined

# %%
#control for independent variable, cofounding factor: number of tweets
import matplotlib
matplotlib.pyplot.close("all")

# %%
query = "select domain_name, round(avg(nominate_dim1),3) AS nominate_dim1, round(avg(nominate_dim2),3) AS nominate_dim2, total from filtered_table GROUP BY domain_name, total"

results = engine.execute(F"Select * from filtered_table").fetchall()
results[:2]
# Out:
# [('www.vox.com', Decimal('-0.380'), Decimal('0.117'), 268),
#  ('www.chicagotribune.com', Decimal('0.509'), Decimal('0.021'), 356)]

# %%
query = "select domain_name, round(avg(nominate_dim1),3) AS nominate_dim1, round(avg(nominate_dim2),3) AS nominate_dim2, sum(total) from filtered_table GROUP BY domain_name"
results = engine.execute(query).fetchall()

# %%
results[:2]
# Out:
# [('thinkprogress.org', Decimal('-0.422'), Decimal('-0.201'), Decimal('434013')),
#  ('www.msnbc.com', Decimal('-0.387'), Decimal('-0.140'), Decimal('433337'))]

# %% [markdown]
# y = x + z
# where
# y = estimated nominate_dim1
# x = avg(nominate_dim1 of politicians)
# z = avg(number of tweets from politicians)

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame(results,columns=["Site","nominate_dim1","nominate_dim2", 'total'])
df = df.astype({'nominate_dim1':'float32','nominate_dim2':'float32', 'total':'int64'})

dim1_ls = np.array(df['nominate_dim1']).reshape(-1, 1)
total_ls = list(df['total'])

# %%
plt.close('all')

# %%
query2 ="select domain_name, round(avg(nominate_dim1),3) AS nominate_dim1, round(avg(nominate_dim2),3) AS nominate_dim2, stddev_samp(total) from filtered_table GROUP BY domain_name"
query2 ="select domain_name, round(avg(nominate_dim1),3) AS nominate_dim1, round(avg(nominate_dim2),3) AS nominate_dim2 from filtered_table GROUP BY domain_name"
results2 = engine.execute(query2).fetchall()
import pandas as pd
df2 = pd.DataFrame(results2,columns=["Site","nominate_dim1","nominate_dim2"])#, 'std_dev'])
df2 = df2.astype({'nominate_dim1':'float32','nominate_dim2':'float32'})#, 'std_dev':'float32'})

# %%
dim1_ls2 = np.array(df2['nominate_dim1']).reshape(-1, 1)
std_ls = list(df2['std_dev'])

# %%
plt.close('all')

# %%
df2
# Out:
#                           Site  nominate_dim1  nominate_dim2
# 0            thinkprogress.org         -0.422         -0.201
# 1                www.msnbc.com         -0.387         -0.140
# 2                    slate.com         -0.421         -0.242
# 3            www.bloomberg.com         -0.052         -0.077
# 4                   reason.com          0.535         -0.725
# 5                  thehill.com         -0.098         -0.090
# 6       www.washingtonpost.com         -0.305         -0.146
# 7              www.foxnews.com          0.515          0.051
# 8             www.politico.com         -0.176         -0.091
# 9                   apple.news          0.098         -0.019
# 10             www.reuters.com         -0.036         -0.085
# 11            www.buzzfeed.com         -0.336         -0.158
# 12              www.apnews.com         -0.049         -0.045
# 13           www.dailywire.com          0.605         -0.026
# 14                 www.vox.com         -0.434         -0.176
# 15              freebeacon.com          0.538         -0.015
# 16                 www.wsj.com          0.290         -0.038
# 17             www.nytimes.com         -0.326         -0.164
# 18  www.conservativereview.com          0.691         -0.246
# 19            www.usatoday.com         -0.092         -0.094
# 20           www.breitbart.com          0.627         -0.100
# 21         www.nydailynews.com         -0.404         -0.212
# 22         www.foxbusiness.com          0.503          0.066
# 23            theintercept.com         -0.454         -0.284
# 24                 www.pbs.org         -0.312         -0.155
# 25  www.washingtonexaminer.com          0.484         -0.015
# 26      www.chicagotribune.com         -0.284         -0.108
# 27         www.motherjones.com         -0.465         -0.195
# 28               www.axios.com         -0.098         -0.090
# 29             www.nbcnews.com         -0.324         -0.131
# 30           thefederalist.com          0.578          0.018
# 31                 www.cnn.com         -0.293         -0.138
# 32                 www.npr.org         -0.347         -0.129
# 33      www.nationalreview.com          0.545         -0.019
# 34           www.newyorker.com         -0.360         -0.179
# 35                  nypost.com          0.234          0.014
# 36      www.huffingtonpost.com         -0.426         -0.181

# %%
df4= df2.sort_values(by="nominate_dim1").reset_index(drop=True).reset_index(drop=True)
df4.head()
# Out:
#                      Site  nominate_dim1  nominate_dim2
# 0     www.motherjones.com         -0.465         -0.195
# 1        theintercept.com         -0.454         -0.284
# 2             www.vox.com         -0.434         -0.176
# 3  www.huffingtonpost.com         -0.426         -0.181
# 4       thinkprogress.org         -0.422         -0.201

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from sklearn import neighbors, datasets

n_neighbors=13

target = [0]*12 + [1] *13 + [2] * 12
dim1 = list(df4['nominate_dim1'])
dim2 = list(df4['nominate_dim2'])

X = np.array([[x, dim2[i]] for i, x in enumerate(dim1)])
y=target

h= .02


cmap_light = ListedColormap(['orange', 'cyan', 'cornflowerblue'])
cmap_bold = ListedColormap(['darkorange', 'c', 'darkblue'])

for weights in ['uniform', 'distance']:
    # we create an instance of Neighbours Classifier and fit the data.
    clf = neighbors.KNeighborsClassifier(n_neighbors, weights=weights)
    clf.fit(X, y)

    # Plot the decision boundary. For that, we will assign a color to each
    # point in the mesh [x_min, x_max]x[y_min, y_max].
    x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
    y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                         np.arange(y_min, y_max, h))
    Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])

    # Put the result into a color plot
    Z = Z.reshape(xx.shape)
    plt.figure()
    plt.pcolormesh(xx, yy, Z, cmap=cmap_light)

    # Plot also the training points
    plt.scatter(X[:, 0], X[:, 1], c=y, cmap=cmap_bold,
                edgecolor='k', s=20)
    plt.xlim(xx.min(), xx.max())
    plt.ylim(yy.min(), yy.max())
    plt.title("3-Class classification (k = %i, weights = '%s')"
              % (n_neighbors, weights))

plt.show()

# %%
point = np.array([-0.465, -0.195]).reshape(1,-1)

clf.predict(point)

predictions = []
for pt in X:
    pt = pt.reshape(1,-1)
    p = clf.predict(pt)
    if p[0] == 0:
        p_label = 'Liberal'
    elif p[0] == 1:
        p_label = 'Moderate'
    else:
        p_label = 'Conservative'
    predictions.append(p_label)

# %%
df4['Group'] = predictions
df4
# Out:
#     index                        Site  nominate_dim1  nominate_dim2  count  \
# 0       0         www.motherjones.com         -0.465         -0.195    300
# 1       1            theintercept.com         -0.454         -0.284    216
# 2       2                 www.vox.com         -0.434         -0.176   2030
# 3       3      www.huffingtonpost.com         -0.424         -0.189   1485
# 4       4           thinkprogress.org         -0.422         -0.201    320
# 5       5                   slate.com         -0.421         -0.242    181
# 6       6         www.nydailynews.com         -0.404         -0.212    329
# 7       7               www.msnbc.com         -0.387         -0.140    421
# 8       8           www.newyorker.com         -0.360         -0.179    270
# 9       9            www.buzzfeed.com         -0.359         -0.167    645
# 10     10                 www.npr.org         -0.345         -0.128   1890
# 11     11             www.nytimes.com         -0.325         -0.163  11140
# 12     12             www.nbcnews.com         -0.317         -0.123   2300
# 13     13                 www.pbs.org         -0.312         -0.155    262
# 14     14      www.washingtonpost.com         -0.300         -0.145  11607
# 15     15                 www.cnn.com         -0.292         -0.136   3541
# 16     16      www.chicagotribune.com         -0.284         -0.108    522
# 17     17            www.politico.com         -0.177         -0.094   3708
# 18     18               www.axios.com         -0.098         -0.090    766
# 19     19                 thehill.com         -0.098         -0.090   4295
# 20     20            www.usatoday.com         -0.097         -0.090   2189
# 21     21           www.bloomberg.com         -0.052         -0.077   1297
# 22     22              www.apnews.com          0.005         -0.015   1811
# 23     23             www.reuters.com          0.027         -0.050   1099
# 24     24                  apple.news          0.098         -0.019    410
# 25     25                  nypost.com          0.234          0.014    281
# 26     26                 www.wsj.com          0.284         -0.033   2680
# 27     27         www.foxbusiness.com          0.481          0.041    551
# 28     28  www.washingtonexaminer.com          0.484         -0.015   1713
# 29     29             www.foxnews.com          0.509          0.041   3171
# 30     30                  reason.com          0.535         -0.725    220
# 31     31              freebeacon.com          0.538         -0.015    462
# 32     32      www.nationalreview.com          0.545         -0.019    468
# 33     33           thefederalist.com          0.578          0.018    251
# 34     34           www.dailywire.com          0.605         -0.026    169
# 35     35           www.breitbart.com          0.627         -0.100    615
# 36     36  www.conservativereview.com          0.691         -0.246    132
#
#            Group
# 0        Liberal
# 1        Liberal
# 2        Liberal
# 3        Liberal
# 4        Liberal
# 5        Liberal
# 6        Liberal
# 7        Liberal
# 8        Liberal
# 9        Liberal
# 10       Liberal
# 11       Liberal
# 12      Moderate
# 13      Moderate
# 14      Moderate
# 15      Moderate
# 16      Moderate
# 17      Moderate
# 18      Moderate
# 19      Moderate
# 20      Moderate
# 21      Moderate
# 22      Moderate
# 23      Moderate
# 24      Moderate
# 25  Conservative
# 26  Conservative
# 27  Conservative
# 28  Conservative
# 29  Conservative
# 30  Conservative
# 31  Conservative
# 32  Conservative
# 33  Conservative
# 34  Conservative
# 35  Conservative
# 36  Conservative

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from sklearn import neighbors, datasets

n_neighbors=8

target2 = [0]*7 + [1] *8 + [2] * 7 + [3]*8 + [4] *7
dim1 = list(df4['nominate_dim1'])
dim2 = list(df4['nominate_dim2'])

X = np.array([[x, dim2[i]] for i, x in enumerate(dim1)])
y=target2

h= .02


cmap_light = ListedColormap(['cornflowerblue','cyan','grey', 'orange', 'red'])
cmap_bold = ListedColormap(['darkblue', 'c', 'slategray', 'darkorange', 'firebrick'])

for weights in ['uniform', 'distance']:
    # we create an instance of Neighbours Classifier and fit the data.
    clf = neighbors.KNeighborsClassifier(n_neighbors, weights=weights)
    clf.fit(X, y)

    # Plot the decision boundary. For that, we will assign a color to each
    # point in the mesh [x_min, x_max]x[y_min, y_max].
    x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
    y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                         np.arange(y_min, y_max, h))
    Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])

    # Put the result into a color plot
    Z = Z.reshape(xx.shape)
    plt.figure()
    plt.pcolormesh(xx, yy, Z, cmap=cmap_light)

    # Plot also the training points
    plt.scatter(X[:, 0], X[:, 1], c=y, cmap=cmap_bold,
                edgecolor='k', s=20)
    plt.xlim(xx.min(), xx.max())
    plt.ylim(yy.min(), yy.max())
    plt.title("5-Class classification (k = %i, weights = '%s')"
              % (n_neighbors, weights))

plt.savefig('static/images/5class.png')

# %%
predictions = []
for pt in X:
    pt = pt.reshape(1,-1)
    p = clf.predict(pt)
    if p[0] == 0:
        p_label = 'Left'
    elif p[0] == 1:
        p_label = 'Left-Leaning'
    elif p[0] == 2:
        p_label = 'Moderate'
    elif p[0] == 3:
        p_label = 'Right-Leaning'
    else:
        p_label = 'Right'
    predictions.append(p_label)
df4['Group'] = predictions
df4
# Out:
#                           Site  nominate_dim1  nominate_dim2          Group
# 0          www.motherjones.com         -0.465         -0.195           Left
# 1             theintercept.com         -0.454         -0.284           Left
# 2                  www.vox.com         -0.434         -0.176           Left
# 3       www.huffingtonpost.com         -0.426         -0.181           Left
# 4            thinkprogress.org         -0.422         -0.201           Left
# 5                    slate.com         -0.421         -0.242           Left
# 6          www.nydailynews.com         -0.404         -0.212           Left
# 7                www.msnbc.com         -0.387         -0.140   Left-Leaning
# 8            www.newyorker.com         -0.360         -0.179   Left-Leaning
# 9                  www.npr.org         -0.347         -0.129   Left-Leaning
# 10            www.buzzfeed.com         -0.336         -0.158   Left-Leaning
# 11             www.nytimes.com         -0.326         -0.164   Left-Leaning
# 12             www.nbcnews.com         -0.324         -0.131   Left-Leaning
# 13                 www.pbs.org         -0.312         -0.155   Left-Leaning
# 14      www.washingtonpost.com         -0.305         -0.146   Left-Leaning
# 15                 www.cnn.com         -0.293         -0.138       Moderate
# 16      www.chicagotribune.com         -0.284         -0.108       Moderate
# 17            www.politico.com         -0.176         -0.091       Moderate
# 18               www.axios.com         -0.098         -0.090       Moderate
# 19                 thehill.com         -0.098         -0.090       Moderate
# 20            www.usatoday.com         -0.092         -0.094       Moderate
# 21           www.bloomberg.com         -0.052         -0.077       Moderate
# 22              www.apnews.com         -0.049         -0.045  Right-Leaning
# 23             www.reuters.com         -0.036         -0.085  Right-Leaning
# 24                  apple.news          0.098         -0.019  Right-Leaning
# 25                  nypost.com          0.234          0.014  Right-Leaning
# 26                 www.wsj.com          0.290         -0.038  Right-Leaning
# 27  www.washingtonexaminer.com          0.484         -0.015  Right-Leaning
# 28         www.foxbusiness.com          0.503          0.066  Right-Leaning
# 29             www.foxnews.com          0.515          0.051  Right-Leaning
# 30                  reason.com          0.535         -0.725          Right
# 31              freebeacon.com          0.538         -0.015          Right
# 32      www.nationalreview.com          0.545         -0.019          Right
# 33           thefederalist.com          0.578          0.018          Right
# 34           www.dailywire.com          0.605         -0.026          Right
# 35           www.breitbart.com          0.627         -0.100          Right
# 36  www.conservativereview.com          0.691         -0.246          Right

# %%
with open('./templates/classify_df.html','w') as fp:
    df4.to_html(fp)

# %%
query = "select domain_name, round(avg(nominate_dim1),3) AS nominate_dim1, round(avg(nominate_dim2),3) AS nominate_dim2, count(domain_name), round(stddev_samp(nominate_dim1),3) AS dim1_stddev, round(stddev_samp(nominate_dim2),3) AS dim2_stddev from filtered_table GROUP BY domain_name"
results5 = engine.execute(query).fetchall()

import pandas as pd
df5 = pd.DataFrame(results5,columns=["Site","nominate_dim1","nominate_dim2", 'count', 'dim1_stddev', 'dim2_stddev'])
df5 = df5.astype({'nominate_dim1':'float','nominate_dim2':'float', 'dim1_stddev':'float', 'dim2_stddev':'float32'})
dim1_ls5 = np.array(df5['nominate_dim1']).reshape(-1, 1)

dim1_stddev =  np.array(df5['dim1_stddev']).reshape(-1, 1)
count_ls5 = list(df5['count'])
df5
# Out:
#                           Site  nominate_dim1  nominate_dim2  count  \
# 0            thinkprogress.org         -0.422         -0.201    320
# 1                www.msnbc.com         -0.387         -0.140    421
# 2                    slate.com         -0.421         -0.242    181
# 3            www.bloomberg.com         -0.052         -0.077   1297
# 4                   reason.com          0.535         -0.725    220
# 5                  thehill.com         -0.098         -0.090   4295
# 6       www.washingtonpost.com         -0.305         -0.146   9856
# 7              www.foxnews.com          0.515          0.051   2095
# 8             www.politico.com         -0.176         -0.091   3399
# 9                   apple.news          0.098         -0.019    410
# 10             www.reuters.com         -0.036         -0.085    877
# 11            www.buzzfeed.com         -0.336         -0.158    367
# 12              www.apnews.com         -0.049         -0.045    453
# 13           www.dailywire.com          0.605         -0.026    169
# 14                 www.vox.com         -0.434         -0.176   2030
# 15              freebeacon.com          0.538         -0.015    462
# 16                 www.wsj.com          0.290         -0.038   2518
# 17             www.nytimes.com         -0.326         -0.164   9073
# 18  www.conservativereview.com          0.691         -0.246    132
# 19            www.usatoday.com         -0.092         -0.094   1947
# 20           www.breitbart.com          0.627         -0.100    615
# 21         www.nydailynews.com         -0.404         -0.212    329
# 22         www.foxbusiness.com          0.503          0.066    360
# 23            theintercept.com         -0.454         -0.284    216
# 24                 www.pbs.org         -0.312         -0.155    262
# 25  www.washingtonexaminer.com          0.484         -0.015   1713
# 26      www.chicagotribune.com         -0.284         -0.108    522
# 27         www.motherjones.com         -0.465         -0.195    300
# 28               www.axios.com         -0.098         -0.090    766
# 29             www.nbcnews.com         -0.324         -0.131   1874
# 30           thefederalist.com          0.578          0.018    251
# 31                 www.cnn.com         -0.293         -0.138   3224
# 32                 www.npr.org         -0.347         -0.129   1712
# 33      www.nationalreview.com          0.545         -0.019    468
# 34           www.newyorker.com         -0.360         -0.179    270
# 35                  nypost.com          0.234          0.014    281
# 36      www.huffingtonpost.com         -0.426         -0.181   1148
#
#     dim1_stddev  dim2_stddev
# 0         0.166        0.213
# 1         0.236        0.240
# 2         0.239        0.214
# 3         0.470        0.243
# 4         0.245        0.272
# 5         0.474        0.253
# 6         0.327        0.226
# 7         0.248        0.266
# 8         0.434        0.246
# 9         0.530        0.240
# 10        0.478        0.249
# 11        0.330        0.233
# 12        0.463        0.262
# 13        0.227        0.306
# 14        0.180        0.222
# 15        0.185        0.208
# 16        0.423        0.221
# 17        0.320        0.222
# 18        0.166        0.348
# 19        0.464        0.243
# 20        0.156        0.361
# 21        0.247        0.179
# 22        0.203        0.244
# 23        0.295        0.271
# 24        0.325        0.251
# 25        0.289        0.266
# 26        0.279        0.233
# 27        0.169        0.200
# 28        0.453        0.250
# 29        0.327        0.240
# 30        0.156        0.317
# 31        0.349        0.237
# 32        0.289        0.234
# 33        0.207        0.304
# 34        0.295        0.245
# 35        0.463        0.256
# 36        0.196        0.213

# %%
def calcStdErr(df, list_ls):
    import math
    for l in list_ls:
        yield [round(x/math.sqrt(count_ls5[i]-1),3) for i, x in enumerate(df5[l])]

# %%
import math
std_err_ls = [x/math.sqrt(count_ls5[i]) for i, x in enumerate(dim1_stddev)]

# %%
results_json3 = list()
for i, r in enumerate(results5):
    r_dict = {}
    r_dict['site'] = r[0]
    r_dict['nominate_dim1'] = float(r[1])
    r_dict['nominate_dim2'] = float(r[2])
    r_dict['total'] = r[3]
    r_dict['dim1_stddev'] = float(r[4])
    r_dict['dim2_stddev'] = float(r[5])
    r_dict['dim1_stderr'] = round(float(std_err_ls[i]),3)
    results_json3.append(r_dict)

# %%
results_json3
# Out:
# [{'site': 'thinkprogress.org',
#   'nominate_dim1': -0.422,
#   'nominate_dim2': -0.201,
#   'total': 320,
#   'dim1_stddev': 0.166,
#   'dim2_stddev': 0.213,
#   'dim1_stderr': 0.009},
#  {'site': 'www.msnbc.com',
#   'nominate_dim1': -0.387,
#   'nominate_dim2': -0.14,
#   'total': 421,
#   'dim1_stddev': 0.236,
#   'dim2_stddev': 0.24,
#   'dim1_stderr': 0.012},
#  {'site': 'www.bloomberg.com',
#   'nominate_dim1': -0.052,
#   'nominate_dim2': -0.077,
#   'total': 1297,
#   'dim1_stddev': 0.47,
#   'dim2_stddev': 0.243,
#   'dim1_stderr': 0.013},
#  {'site': 'slate.com',
#   'nominate_dim1': -0.421,
#   'nominate_dim2': -0.242,
#   'total': 181,
#   'dim1_stddev': 0.239,
#   'dim2_stddev': 0.214,
#   'dim1_stderr': 0.018},
#  {'site': 'reason.com',
#   'nominate_dim1': 0.535,
#   'nominate_dim2': -0.725,
#   'total': 220,
#   'dim1_stddev': 0.245,
#   'dim2_stddev': 0.272,
#   'dim1_stderr': 0.017},
#  {'site': 'thehill.com',
#   'nominate_dim1': -0.098,
#   'nominate_dim2': -0.09,
#   'total': 4295,
#   'dim1_stddev': 0.474,
#   'dim2_stddev': 0.253,
#   'dim1_stderr': 0.007},
#  {'site': 'www.washingtonpost.com',
#   'nominate_dim1': -0.3,
#   'nominate_dim2': -0.145,
#   'total': 11607,
#   'dim1_stddev': 0.331,
#   'dim2_stddev': 0.224,
#   'dim1_stderr': 0.003},
#  {'site': 'www.foxnews.com',
#   'nominate_dim1': 0.509,
#   'nominate_dim2': 0.041,
#   'total': 3171,
#   'dim1_stddev': 0.255,
#   'dim2_stddev': 0.272,
#   'dim1_stderr': 0.005},
#  {'site': 'www.politico.com',
#   'nominate_dim1': -0.177,
#   'nominate_dim2': -0.094,
#   'total': 3708,
#   'dim1_stddev': 0.433,
#   'dim2_stddev': 0.245,
#   'dim1_stderr': 0.007},
#  {'site': 'apple.news',
#   'nominate_dim1': 0.098,
#   'nominate_dim2': -0.019,
#   'total': 410,
#   'dim1_stddev': 0.53,
#   'dim2_stddev': 0.24,
#   'dim1_stderr': 0.026},
#  {'site': 'www.buzzfeed.com',
#   'nominate_dim1': -0.359,
#   'nominate_dim2': -0.167,
#   'total': 645,
#   'dim1_stddev': 0.304,
#   'dim2_stddev': 0.231,
#   'dim1_stderr': 0.012},
#  {'site': 'www.reuters.com',
#   'nominate_dim1': 0.027,
#   'nominate_dim2': -0.05,
#   'total': 1099,
#   'dim1_stddev': 0.483,
#   'dim2_stddev': 0.254,
#   'dim1_stderr': 0.015},
#  {'site': 'www.apnews.com',
#   'nominate_dim1': 0.005,
#   'nominate_dim2': -0.015,
#   'total': 1811,
#   'dim1_stddev': 0.477,
#   'dim2_stddev': 0.263,
#   'dim1_stderr': 0.011},
#  {'site': 'www.dailywire.com',
#   'nominate_dim1': 0.605,
#   'nominate_dim2': -0.026,
#   'total': 169,
#   'dim1_stddev': 0.227,
#   'dim2_stddev': 0.306,
#   'dim1_stderr': 0.017},
#  {'site': 'www.vox.com',
#   'nominate_dim1': -0.434,
#   'nominate_dim2': -0.176,
#   'total': 2030,
#   'dim1_stddev': 0.18,
#   'dim2_stddev': 0.222,
#   'dim1_stderr': 0.004},
#  {'site': 'freebeacon.com',
#   'nominate_dim1': 0.538,
#   'nominate_dim2': -0.015,
#   'total': 462,
#   'dim1_stddev': 0.185,
#   'dim2_stddev': 0.208,
#   'dim1_stderr': 0.009},
#  {'site': 'www.wsj.com',
#   'nominate_dim1': 0.284,
#   'nominate_dim2': -0.033,
#   'total': 2680,
#   'dim1_stddev': 0.425,
#   'dim2_stddev': 0.221,
#   'dim1_stderr': 0.008},
#  {'site': 'www.nytimes.com',
#   'nominate_dim1': -0.325,
#   'nominate_dim2': -0.163,
#   'total': 11140,
#   'dim1_stddev': 0.321,
#   'dim2_stddev': 0.219,
#   'dim1_stderr': 0.003},
#  {'site': 'www.conservativereview.com',
#   'nominate_dim1': 0.691,
#   'nominate_dim2': -0.246,
#   'total': 132,
#   'dim1_stddev': 0.166,
#   'dim2_stddev': 0.348,
#   'dim1_stderr': 0.014},
#  {'site': 'www.usatoday.com',
#   'nominate_dim1': -0.097,
#   'nominate_dim2': -0.09,
#   'total': 2189,
#   'dim1_stddev': 0.461,
#   'dim2_stddev': 0.242,
#   'dim1_stderr': 0.01},
#  {'site': 'www.breitbart.com',
#   'nominate_dim1': 0.627,
#   'nominate_dim2': -0.1,
#   'total': 615,
#   'dim1_stddev': 0.156,
#   'dim2_stddev': 0.361,
#   'dim1_stderr': 0.006},
#  {'site': 'www.nydailynews.com',
#   'nominate_dim1': -0.404,
#   'nominate_dim2': -0.212,
#   'total': 329,
#   'dim1_stddev': 0.247,
#   'dim2_stddev': 0.179,
#   'dim1_stderr': 0.014},
#  {'site': 'theintercept.com',
#   'nominate_dim1': -0.454,
#   'nominate_dim2': -0.284,
#   'total': 216,
#   'dim1_stddev': 0.295,
#   'dim2_stddev': 0.271,
#   'dim1_stderr': 0.02},
#  {'site': 'www.foxbusiness.com',
#   'nominate_dim1': 0.481,
#   'nominate_dim2': 0.041,
#   'total': 551,
#   'dim1_stddev': 0.25,
#   'dim2_stddev': 0.245,
#   'dim1_stderr': 0.011},
#  {'site': 'www.pbs.org',
#   'nominate_dim1': -0.312,
#   'nominate_dim2': -0.155,
#   'total': 262,
#   'dim1_stddev': 0.325,
#   'dim2_stddev': 0.251,
#   'dim1_stderr': 0.02},
#  {'site': 'www.washingtonexaminer.com',
#   'nominate_dim1': 0.484,
#   'nominate_dim2': -0.015,
#   'total': 1713,
#   'dim1_stddev': 0.289,
#   'dim2_stddev': 0.266,
#   'dim1_stderr': 0.007},
#  {'site': 'www.motherjones.com',
#   'nominate_dim1': -0.465,
#   'nominate_dim2': -0.195,
#   'total': 300,
#   'dim1_stddev': 0.169,
#   'dim2_stddev': 0.2,
#   'dim1_stderr': 0.01},
#  {'site': 'www.chicagotribune.com',
#   'nominate_dim1': -0.284,
#   'nominate_dim2': -0.108,
#   'total': 522,
#   'dim1_stddev': 0.279,
#   'dim2_stddev': 0.233,
#   'dim1_stderr': 0.012},
#  {'site': 'www.axios.com',
#   'nominate_dim1': -0.098,
#   'nominate_dim2': -0.09,
#   'total': 766,
#   'dim1_stddev': 0.453,
#   'dim2_stddev': 0.25,
#   'dim1_stderr': 0.016},
#  {'site': 'www.nbcnews.com',
#   'nominate_dim1': -0.317,
#   'nominate_dim2': -0.123,
#   'total': 2300,
#   'dim1_stddev': 0.329,
#   'dim2_stddev': 0.238,
#   'dim1_stderr': 0.007},
#  {'site': 'thefederalist.com',
#   'nominate_dim1': 0.578,
#   'nominate_dim2': 0.018,
#   'total': 251,
#   'dim1_stddev': 0.156,
#   'dim2_stddev': 0.317,
#   'dim1_stderr': 0.01},
#  {'site': 'www.cnn.com',
#   'nominate_dim1': -0.292,
#   'nominate_dim2': -0.136,
#   'total': 3541,
#   'dim1_stddev': 0.351,
#   'dim2_stddev': 0.235,
#   'dim1_stderr': 0.006},
#  {'site': 'www.npr.org',
#   'nominate_dim1': -0.345,
#   'nominate_dim2': -0.128,
#   'total': 1890,
#   'dim1_stddev': 0.287,
#   'dim2_stddev': 0.232,
#   'dim1_stderr': 0.007},
#  {'site': 'www.nationalreview.com',
#   'nominate_dim1': 0.545,
#   'nominate_dim2': -0.019,
#   'total': 468,
#   'dim1_stddev': 0.207,
#   'dim2_stddev': 0.304,
#   'dim1_stderr': 0.01},
#  {'site': 'www.newyorker.com',
#   'nominate_dim1': -0.36,
#   'nominate_dim2': -0.179,
#   'total': 270,
#   'dim1_stddev': 0.295,
#   'dim2_stddev': 0.245,
#   'dim1_stderr': 0.018},
#  {'site': 'nypost.com',
#   'nominate_dim1': 0.234,
#   'nominate_dim2': 0.014,
#   'total': 281,
#   'dim1_stddev': 0.463,
#   'dim2_stddev': 0.256,
#   'dim1_stderr': 0.028},
#  {'site': 'www.huffingtonpost.com',
#   'nominate_dim1': -0.424,
#   'nominate_dim2': -0.189,
#   'total': 1485,
#   'dim1_stddev': 0.194,
#   'dim2_stddev': 0.227,
#   'dim1_stderr': 0.005}]

# %%
import json
with open('mainmediaorgs2.json', 'w', encoding='utf-8') as f:
    json.dump(results_json3, f, ensure_ascii=False, indent=4)

# %%
gop_query = "select domain_name, round(avg(nominate_dim1),3) AS nominate_dim1, round(avg(nominate_dim2),3) AS nominate_dim2, count(domain_name) from gop_table GROUP BY domain_name"
gop_query = "select domain_name, count(domain_name), round(avg(nominate_dim1),3) AS nominate_dim1, round(avg(nominate_dim2),3) AS nominate_dim2, round(stddev_samp(nominate_dim1),3) AS dim1_stddev, round(stddev_samp(nominate_dim2),3) AS dim2_stddev from gop_table group by domain_name order by count(domain_name) desc"

gop_results = engine.execute(gop_query).fetchall()
import pandas as pd
gop_df = pd.DataFrame(gop_results,columns=["Site","count","gop_dim1","gop_dim2", 'gop_dim1_stddev', 'gop_dim2_stddev'])
gop_df = gop_df.astype({'gop_dim1':'float32','gop_dim2':'float32', 'gop_dim1_stddev':'float32', 'gop_dim2_stddev':'float32'})

gop_df.plot.scatter(x='gop_dim1',y='gop_dim2', xlim=[-1,1], ylim=[-1,1], color='r')

# %%
dem_query = "select domain_name, round(avg(nominate_dim1),3) AS nominate_dim1, round(avg(nominate_dim2),3) AS nominate_dim2, count(domain_name) from dem_table GROUP BY domain_name"
dem_query = "select domain_name, count(domain_name), round(avg(nominate_dim1),3) AS nominate_dim1, round(avg(nominate_dim2),3) AS nominate_dim2, round(stddev_samp(nominate_dim1),3) AS dim1_stddev, round(stddev_samp(nominate_dim2),3) AS dim2_stddev from dem_table group by domain_name order by count(domain_name) desc"
dem_results = engine.execute(dem_query).fetchall()
import pandas as pd
dem_df = pd.DataFrame(dem_results,columns=["Site","count", "dem_dim1","dem_dim2", 'dem_dim1_stddev', 'dem_dim2_stddev'])
dem_df = dem_df.astype({'dem_dim1':'float32','dem_dim2':'float32', 'dem_dim1_stddev':'float32', 'dem_dim2_stddev':'float32'})
dem_df = dem_df.loc[dem_df['count']>1] #conservative review has 1 tweet, no stddev

dem_df.plot.scatter(x='dem_dim1',y='dem_dim2', xlim=[-1,1], ylim=[-1,1])

# %%
dem_df.loc[dem_df['count']>1]
# Out:
#                           Site  count  dem_dim1  dem_dim2  dem_dim1_stddev  \
# 0       www.washingtonpost.com   8604    -0.416    -0.162            0.120
# 1              www.nytimes.com   8024    -0.429    -0.181            0.122
# 2                  thehill.com   2814    -0.425    -0.138            0.123
# 3                  www.cnn.com   2752    -0.424    -0.163            0.122
# 4             www.politico.com   2519    -0.419    -0.150            0.123
# 5                  www.vox.com   1972    -0.448    -0.178            0.134
# 6              www.nbcnews.com   1653    -0.431    -0.149            0.122
# 7                  www.npr.org   1552    -0.426    -0.144            0.126
# 8             www.usatoday.com   1266    -0.407    -0.151            0.130
# 9       www.huffingtonpost.com   1109    -0.448    -0.181            0.129
# 10           www.bloomberg.com    784    -0.414    -0.147            0.122
# 11                 www.wsj.com    641    -0.405    -0.136            0.113
# 12             www.reuters.com    522    -0.408    -0.153            0.121
# 13               www.axios.com    508    -0.401    -0.133            0.114
# 14      www.chicagotribune.com    472    -0.366    -0.122            0.106
# 15               www.msnbc.com    403    -0.429    -0.145            0.123
# 16            www.buzzfeed.com    326    -0.444    -0.184            0.128
# 17         www.nydailynews.com    307    -0.460    -0.229            0.114
# 18           thinkprogress.org    302    -0.433    -0.197            0.115
# 19         www.motherjones.com    288    -0.474    -0.189            0.135
# 20              www.apnews.com    272    -0.407    -0.137            0.117
# 21           www.newyorker.com    246    -0.439    -0.205            0.128
# 22                 www.pbs.org    232    -0.414    -0.184            0.127
# 23            theintercept.com    188    -0.514    -0.294            0.161
# 24                  apple.news    180    -0.489    -0.121            0.129
# 25                   slate.com    173    -0.459    -0.248            0.133
# 26  www.washingtonexaminer.com    130    -0.401    -0.113            0.116
# 27             www.foxnews.com    111    -0.385    -0.087            0.117
# 28                  nypost.com     89    -0.421    -0.190            0.115
# 29      www.nationalreview.com     13    -0.388    -0.239            0.076
# 30         www.foxbusiness.com     12    -0.381    -0.062            0.142
# 31              freebeacon.com      8    -0.391    -0.166            0.087
# 32           www.breitbart.com      7    -0.326    -0.131            0.078
# 33           www.dailywire.com      5    -0.447    -0.328            0.093
# 34                  reason.com      4    -0.524    -0.140            0.130
# 35           thefederalist.com      2    -0.400     0.174            0.005
#
#     dem_dim2_stddev
# 0             0.216
# 1             0.215
# 2             0.213
# 3             0.222
# 4             0.219
# 5             0.220
# 6             0.233
# 7             0.226
# 8             0.212
# 9             0.205
# 10            0.220
# 11            0.207
# 12            0.232
# 13            0.240
# 14            0.220
# 15            0.239
# 16            0.197
# 17            0.165
# 18            0.213
# 19            0.198
# 20            0.236
# 21            0.230
# 22            0.230
# 23            0.273
# 24            0.217
# 25            0.206
# 26            0.238
# 27            0.195
# 28            0.161
# 29            0.198
# 30            0.155
# 31            0.125
# 32            0.176
# 33            0.048
# 34            0.114
# 35            0.057

# %%
df5['dem1_stddev'] = dem_df['dem_dim1_stddev']
df5['dem2_stddev'] = dem_df['dem_dim2_stddev']
df5['gop1_stddev'] = gop_df['gop_dim1_stddev']
df5['gop2_stddev'] = gop_df['gop_dim2_stddev']
df5['dem1'] = dem_df['dem_dim1']
df5['dem2'] = dem_df['dem_dim2']
df5['gop1'] = gop_df['gop_dim1']
df5['gop2'] = gop_df['gop_dim2']

# %%
df5
# Out:
#                           Site  nominate_dim1  nominate_dim2  count  \
# 0            thinkprogress.org         -0.422         -0.201    320
# 1                www.msnbc.com         -0.387         -0.140    421
# 2                    slate.com         -0.421         -0.242    181
# 3            www.bloomberg.com         -0.052         -0.077   1297
# 4                   reason.com          0.535         -0.725    220
# 5                  thehill.com         -0.098         -0.090   4295
# 6       www.washingtonpost.com         -0.305         -0.146   9856
# 7              www.foxnews.com          0.515          0.051   2095
# 8             www.politico.com         -0.176         -0.091   3399
# 9                   apple.news          0.098         -0.019    410
# 10             www.reuters.com         -0.036         -0.085    877
# 11            www.buzzfeed.com         -0.336         -0.158    367
# 12              www.apnews.com         -0.049         -0.045    453
# 13           www.dailywire.com          0.605         -0.026    169
# 14                 www.vox.com         -0.434         -0.176   2030
# 15              freebeacon.com          0.538         -0.015    462
# 16                 www.wsj.com          0.290         -0.038   2518
# 17             www.nytimes.com         -0.326         -0.164   9073
# 18            www.usatoday.com         -0.092         -0.094   1947
# 19           www.breitbart.com          0.627         -0.100    615
# 20         www.nydailynews.com         -0.404         -0.212    329
# 21         www.foxbusiness.com          0.503          0.066    360
# 22            theintercept.com         -0.454         -0.284    216
# 23                 www.pbs.org         -0.312         -0.155    262
# 24  www.washingtonexaminer.com          0.484         -0.015   1713
# 25      www.chicagotribune.com         -0.284         -0.108    522
# 26         www.motherjones.com         -0.465         -0.195    300
# 27               www.axios.com         -0.098         -0.090    766
# 28             www.nbcnews.com         -0.324         -0.131   1874
# 29           thefederalist.com          0.578          0.018    251
# 30                 www.cnn.com         -0.293         -0.138   3224
# 31                 www.npr.org         -0.347         -0.129   1712
# 32      www.nationalreview.com          0.545         -0.019    468
# 33           www.newyorker.com         -0.360         -0.179    270
# 34                  nypost.com          0.234          0.014    281
# 35      www.huffingtonpost.com         -0.426         -0.181   1148
#
#     dim1_stddev  dim2_stddev  dem1_stddev  dem2_stddev  gop1_stddev  \
# 0         0.166        0.213        0.120        0.216        0.126
# 1         0.236        0.240        0.122        0.215        0.112
# 2         0.239        0.214        0.123        0.213        0.138
# 3         0.470        0.243        0.122        0.222        0.146
# 4         0.245        0.272        0.123        0.219        0.125
# 5         0.474        0.253        0.134        0.220        0.117
# 6         0.327        0.226        0.122        0.233        0.108
# 7         0.248        0.266        0.126        0.226        0.144
# 8         0.434        0.246        0.130        0.212        0.118
# 9         0.530        0.240        0.129        0.205        0.124
# 10        0.478        0.249        0.122        0.220        0.139
# 11        0.330        0.233        0.113        0.207        0.132
# 12        0.463        0.262        0.121        0.232        0.139
# 13        0.227        0.306        0.114        0.240        0.119
# 14        0.180        0.222        0.106        0.220        0.118
# 15        0.185        0.208        0.123        0.239        0.120
# 16        0.423        0.221        0.128        0.197        0.128
# 17        0.320        0.222        0.114        0.165        0.075
# 18        0.464        0.243        0.115        0.213        0.133
# 19        0.156        0.361        0.135        0.198        0.127
# 20        0.247        0.179        0.117        0.236        0.104
# 21        0.203        0.244        0.128        0.230        0.134
# 22        0.295        0.271        0.127        0.230        0.141
# 23        0.325        0.251        0.161        0.273        0.099
# 24        0.289        0.266        0.129        0.217        0.124
# 25        0.279        0.233        0.133        0.206        0.115
# 26        0.169        0.200        0.116        0.238        0.093
# 27        0.453        0.250        0.117        0.195        0.100
# 28        0.327        0.240        0.115        0.161        0.148
# 29        0.156        0.317        0.076        0.198        0.110
# 30        0.349        0.237        0.142        0.155        0.074
# 31        0.289        0.234        0.087        0.125        0.132
# 32        0.207        0.304        0.078        0.176        0.175
# 33        0.295        0.245        0.093        0.048        0.114
# 34        0.463        0.256        0.130        0.114        0.157
# 35        0.196        0.213        0.005        0.057        0.170
#
#     gop2_stddev  std_err  dem_err  gop_err   dem1   dem2   gop1   gop2
# 0         0.265    0.009    0.007    0.007 -0.416 -0.162  0.565  0.060
# 1         0.212    0.012    0.006    0.005 -0.429 -0.181  0.530 -0.002
# 2         0.261    0.018    0.009    0.010 -0.425 -0.138  0.558 -0.004
# 3         0.284    0.013    0.003    0.004 -0.424 -0.163  0.538  0.013
# 4         0.243    0.017    0.008    0.008 -0.419 -0.150  0.525 -0.008
# 5         0.219    0.007    0.002    0.002 -0.448 -0.178  0.524 -0.007
# 6         0.233    0.003    0.001    0.001 -0.431 -0.149  0.537  0.085
# 7         0.254    0.005    0.003    0.003 -0.426 -0.144  0.529  0.024
# 8         0.362    0.007    0.002    0.002 -0.407 -0.151  0.638 -0.100
# 9         0.235    0.026    0.006    0.006 -0.448 -0.181  0.516  0.037
# 10        0.208    0.016    0.004    0.005 -0.414 -0.147  0.555 -0.012
# 11        0.283    0.017    0.006    0.007 -0.405 -0.136  0.576  0.002
# 12        0.248    0.022    0.006    0.007 -0.408 -0.153  0.517  0.031
# 13        0.246    0.018    0.009    0.009 -0.401 -0.133  0.533  0.070
# 14        0.235    0.004    0.002    0.003 -0.366 -0.122  0.535  0.022
# 15        0.237    0.009    0.006    0.006 -0.429 -0.145  0.533  0.011
# 16        0.307    0.008    0.003    0.003 -0.444 -0.184  0.589  0.025
# 17        0.227    0.003    0.001    0.001 -0.460 -0.229  0.558  0.060
# 18        0.242    0.041    0.010    0.012 -0.433 -0.197  0.531  0.024
# 19        0.236    0.004    0.003    0.003 -0.474 -0.189  0.538  0.109
# 20        0.214    0.010    0.005    0.004 -0.407 -0.137  0.513  0.111
# 21        0.306    0.011    0.007    0.007 -0.439 -0.205  0.637 -0.017
# 22        0.239    0.016    0.007    0.007 -0.414 -0.184  0.503  0.053
# 23        0.258    0.022    0.011    0.007 -0.514 -0.294  0.695 -0.612
# 24        0.341    0.018    0.008    0.008 -0.489 -0.121  0.704 -0.245
# 25        0.275    0.007    0.003    0.003 -0.459 -0.248  0.519  0.050
# 26        0.288    0.007    0.005    0.004 -0.401 -0.113  0.536  0.098
# 27        0.167    0.026    0.007    0.006 -0.385 -0.087  0.557  0.093
# 28        0.278    0.012    0.004    0.005 -0.421 -0.190  0.548  0.101
# 29        0.356    0.004    0.002    0.003 -0.388 -0.239  0.563 -0.008
# 30        0.197    0.022    0.009    0.005 -0.381 -0.062  0.536  0.132
# 31        0.155    0.005    0.002    0.002 -0.391 -0.166  0.455  0.066
# 32        0.245    0.005    0.002    0.004 -0.326 -0.131  0.555 -0.041
# 33        0.265    0.014    0.004    0.005 -0.447 -0.328  0.584 -0.016
# 34        0.381    0.028    0.008    0.010 -0.524 -0.140  0.643 -0.065
# 35        0.249    0.012    0.000    0.010 -0.400  0.174  0.531  0.037

# %%
import math
df5 = df5.loc[df5['Site']!='www.conservativereview.com'].reset_index(drop=True)

std_err_ls, dem_err_ls, gop_err_ls = calcStdErr(df5, ['dim1_stddev','dem1_stddev','gop1_stddev'])

df5['std_err'] = std_err_ls
df5['dem_err'] = dem_err_ls
df5['gop_err'] = gop_err_ls

# %%
df5.to_json('mainmediaorgs3.json', orient='records')
#Why huffpost no stddev?

# %%
df5
# Out:
#                           Site  nominate_dim1  nominate_dim2  count  \
# 0            thinkprogress.org         -0.422         -0.201    320
# 1                www.msnbc.com         -0.387         -0.140    421
# 2                    slate.com         -0.421         -0.242    181
# 3            www.bloomberg.com         -0.052         -0.077   1297
# 4                   reason.com          0.535         -0.725    220
# 5                  thehill.com         -0.098         -0.090   4295
# 6       www.washingtonpost.com         -0.305         -0.146   9856
# 7              www.foxnews.com          0.515          0.051   2095
# 8             www.politico.com         -0.176         -0.091   3399
# 9                   apple.news          0.098         -0.019    410
# 10             www.reuters.com         -0.036         -0.085    877
# 11            www.buzzfeed.com         -0.336         -0.158    367
# 12              www.apnews.com         -0.049         -0.045    453
# 13           www.dailywire.com          0.605         -0.026    169
# 14                 www.vox.com         -0.434         -0.176   2030
# 15              freebeacon.com          0.538         -0.015    462
# 16                 www.wsj.com          0.290         -0.038   2518
# 17             www.nytimes.com         -0.326         -0.164   9073
# 18            www.usatoday.com         -0.092         -0.094   1947
# 19           www.breitbart.com          0.627         -0.100    615
# 20         www.nydailynews.com         -0.404         -0.212    329
# 21         www.foxbusiness.com          0.503          0.066    360
# 22            theintercept.com         -0.454         -0.284    216
# 23                 www.pbs.org         -0.312         -0.155    262
# 24  www.washingtonexaminer.com          0.484         -0.015   1713
# 25      www.chicagotribune.com         -0.284         -0.108    522
# 26         www.motherjones.com         -0.465         -0.195    300
# 27               www.axios.com         -0.098         -0.090    766
# 28             www.nbcnews.com         -0.324         -0.131   1874
# 29           thefederalist.com          0.578          0.018    251
# 30                 www.cnn.com         -0.293         -0.138   3224
# 31                 www.npr.org         -0.347         -0.129   1712
# 32      www.nationalreview.com          0.545         -0.019    468
# 33           www.newyorker.com         -0.360         -0.179    270
# 34                  nypost.com          0.234          0.014    281
# 35      www.huffingtonpost.com         -0.426         -0.181   1148
#
#     dim1_stddev  dim2_stddev  dem1_stddev  dem2_stddev  gop1_stddev  \
# 0         0.166        0.213        0.120        0.216        0.126
# 1         0.236        0.240        0.122        0.215        0.112
# 2         0.239        0.214        0.123        0.213        0.138
# 3         0.470        0.243        0.122        0.222        0.146
# 4         0.245        0.272        0.123        0.219        0.125
# 5         0.474        0.253        0.134        0.220        0.117
# 6         0.327        0.226        0.122        0.233        0.108
# 7         0.248        0.266        0.126        0.226        0.144
# 8         0.434        0.246        0.130        0.212        0.118
# 9         0.530        0.240        0.129        0.205        0.124
# 10        0.478        0.249        0.122        0.220        0.139
# 11        0.330        0.233        0.113        0.207        0.132
# 12        0.463        0.262        0.121        0.232        0.139
# 13        0.227        0.306        0.114        0.240        0.119
# 14        0.180        0.222        0.106        0.220        0.118
# 15        0.185        0.208        0.123        0.239        0.120
# 16        0.423        0.221        0.128        0.197        0.128
# 17        0.320        0.222        0.114        0.165        0.075
# 18        0.464        0.243        0.115        0.213        0.133
# 19        0.156        0.361        0.135        0.198        0.127
# 20        0.247        0.179        0.117        0.236        0.104
# 21        0.203        0.244        0.128        0.230        0.134
# 22        0.295        0.271        0.127        0.230        0.141
# 23        0.325        0.251        0.161        0.273        0.099
# 24        0.289        0.266        0.129        0.217        0.124
# 25        0.279        0.233        0.133        0.206        0.115
# 26        0.169        0.200        0.116        0.238        0.093
# 27        0.453        0.250        0.117        0.195        0.100
# 28        0.327        0.240        0.115        0.161        0.148
# 29        0.156        0.317        0.076        0.198        0.110
# 30        0.349        0.237        0.142        0.155        0.074
# 31        0.289        0.234        0.087        0.125        0.132
# 32        0.207        0.304        0.078        0.176        0.175
# 33        0.295        0.245        0.093        0.048        0.114
# 34        0.463        0.256        0.130        0.114        0.157
# 35        0.196        0.213        0.005        0.057        0.170
#
#     gop2_stddev  std_err  dem_err  gop_err
# 0         0.265    0.009    0.007    0.007
# 1         0.212    0.012    0.006    0.005
# 2         0.261    0.018    0.009    0.010
# 3         0.284    0.013    0.003    0.004
# 4         0.243    0.017    0.008    0.008
# 5         0.219    0.007    0.002    0.002
# 6         0.233    0.003    0.001    0.001
# 7         0.254    0.005    0.003    0.003
# 8         0.362    0.007    0.002    0.002
# 9         0.235    0.026    0.006    0.006
# 10        0.208    0.016    0.004    0.005
# 11        0.283    0.017    0.006    0.007
# 12        0.248    0.022    0.006    0.007
# 13        0.246    0.018    0.009    0.009
# 14        0.235    0.004    0.002    0.003
# 15        0.237    0.009    0.006    0.006
# 16        0.307    0.008    0.003    0.003
# 17        0.227    0.003    0.001    0.001
# 18        0.242    0.041    0.010    0.012
# 19        0.236    0.004    0.003    0.003
# 20        0.214    0.010    0.005    0.004
# 21        0.306    0.011    0.007    0.007
# 22        0.239    0.016    0.007    0.007
# 23        0.258    0.022    0.011    0.007
# 24        0.341    0.018    0.008    0.008
# 25        0.275    0.007    0.003    0.003
# 26        0.288    0.007    0.005    0.004
# 27        0.167    0.026    0.007    0.006
# 28        0.278    0.012    0.004    0.005
# 29        0.356    0.004    0.002    0.003
# 30        0.197    0.022    0.009    0.005
# 31        0.155    0.005    0.002    0.002
# 32        0.245    0.005    0.002    0.004
# 33        0.265    0.014    0.004    0.005
# 34        0.381    0.028    0.008    0.010
# 35        0.249    0.012    0.000    0.010
